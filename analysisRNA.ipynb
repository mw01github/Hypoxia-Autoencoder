# %%
import os
import pandas as pd

df = pd.DataFrame(columns=[
'ANLN_unstranded', 'ANLN_stranded_first', 'ANLN_stranded_second', 'ANLN_tpm_unstranded', 'ANLN_fpkm_unstranded', 'ANLN_fpkm_uq_unstranded',
'ENO1_unstranded', 'ENO1_stranded_first', 'ENO1_stranded_second', 'ENO1_tpm_unstranded', 'ENO1_fpkm_unstranded', 'ENO1_fpkm_uq_unstranded',
'CDKN3_unstranded', 'CDKN3_stranded_first', 'CDKN3_stranded_second', 'CDKN3_tpm_unstranded', 'CDKN3_fpkm_unstranded', 'CDKN3_fpkm_uq_unstranded',
'PGK1_unstranded', 'PGK1_stranded_first', 'PGK1_stranded_second', 'PGK1_tpm_unstranded', 'PGK1_fpkm_unstranded', 'PGK1_fpkm_uq_unstranded',
'CA9_unstranded', 'CA9_stranded_first', 'CA9_stranded_second', 'CA9_tpm_unstranded', 'CA9_fpkm_unstranded', 'CA9_fpkm_uq_unstranded',
'TPI1_unstranded', 'TPI1_stranded_first', 'TPI1_stranded_second', 'TPI1_tpm_unstranded', 'TPI1_fpkm_unstranded', 'TPI1_fpkm_uq_unstranded',
'VEGFA_unstranded', 'VEGFA_stranded_first', 'VEGFA_stranded_second', 'VEGFA_tpm_unstranded', 'VEGFA_fpkm_unstranded', 'VEGFA_fpkm_uq_unstranded',
'SDC1_unstranded', 'SDC1_stranded_first', 'SDC1_stranded_second', 'SDC1_tpm_unstranded', 'SDC1_fpkm_unstranded', 'SDC1_fpkm_uq_unstranded',
'SLC2A1_unstranded', 'SLC2A1_stranded_first', 'SLC2A1_stranded_second', 'SLC2A1_tpm_unstranded', 'SLC2A1_fpkm_unstranded', 'SLC2A1_fpkm_uq_unstranded',
'P4HA1_unstranded', 'P4HA1_stranded_first', 'P4HA1_stranded_second', 'P4HA1_tpm_unstranded', 'P4HA1_fpkm_unstranded', 'P4HA1_fpkm_uq_unstranded',
'GNAI1_unstranded', 'GNAI1_stranded_first', 'GNAI1_stranded_second', 'GNAI1_tpm_unstranded', 'GNAI1_fpkm_unstranded', 'GNAI1_fpkm_uq_unstranded',
'KRT17_unstranded', 'KRT17_stranded_first', 'KRT17_stranded_second', 'KRT17_tpm_unstranded', 'KRT17_fpkm_unstranded', 'KRT17_fpkm_uq_unstranded',
'LDHA_unstranded', 'LDHA_stranded_first', 'LDHA_stranded_second', 'LDHA_tpm_unstranded', 'LDHA_fpkm_unstranded', 'LDHA_fpkm_uq_unstranded',
'ALDOA_unstranded', 'ALDOA_stranded_first', 'ALDOA_stranded_second', 'ALDOA_tpm_unstranded', 'ALDOA_fpkm_unstranded', 'ALDOA_fpkm_uq_unstranded',
'SLC16A1_unstranded', 'SLC16A1_stranded_first', 'SLC16A1_stranded_second', 'SLC16A1_tpm_unstranded', 'SLC16A1_fpkm_unstranded', 'SLC16A1_fpkm_uq_unstranded',
'DCBLD1_unstranded', 'DCBLD1_stranded_first', 'DCBLD1_stranded_second', 'DCBLD1_tpm_unstranded', 'DCBLD1_fpkm_unstranded', 'DCBLD1_fpkm_uq_unstranded',
'ANGPTL4_unstranded', 'ANGPTL4_stranded_first', 'ANGPTL4_stranded_second', 'ANGPTL4_tpm_unstranded', 'ANGPTL4_fpkm_unstranded', 'ANGPTL4_fpkm_uq_unstranded',
'FAM83B_unstranded', 'FAM83B_stranded_first', 'FAM83B_stranded_second', 'FAM83B_tpm_unstranded', 'FAM83B_fpkm_unstranded', 'FAM83B_fpkm_uq_unstranded',
'BNC1_unstranded', 'BNC1_stranded_first', 'BNC1_stranded_second', 'BNC1_tpm_unstranded', 'BNC1_fpkm_unstranded', 'BNC1_fpkm_uq_unstranded',
'PGAM1_unstranded', 'PGAM1_stranded_first', 'PGAM1_stranded_second', 'PGAM1_tpm_unstranded', 'PGAM1_fpkm_unstranded', 'PGAM1_fpkm_uq_unstranded',
'FOSL1_unstranded', 'FOSL1_stranded_first', 'FOSL1_stranded_second', 'FOSL1_tpm_unstranded', 'FOSL1_fpkm_unstranded', 'FOSL1_fpkm_uq_unstranded',
'COL4A6_unstranded', 'COL4A6_stranded_first', 'COL4A6_stranded_second', 'COL4A6_tpm_unstranded', 'COL4A6_fpkm_unstranded', 'COL4A6_fpkm_uq_unstranded',
'KCTD11_unstranded', 'KCTD11_stranded_first', 'KCTD11_stranded_second', 'KCTD11_tpm_unstranded', 'KCTD11_fpkm_unstranded', 'KCTD11_fpkm_uq_unstranded',])

directory_path = 'gdc_download_20240201_205130.883037'
folders = [entry.name for entry in os.scandir(directory_path) if entry.is_dir()]

for i in folders:
    file = [entry.name for entry in os.scandir(directory_path + '/' + i) if entry.is_file() and entry.name[-4:] == '.tsv'][0]
    df1 = pd.read_csv(directory_path + '/' + i + '/' + file, sep='\t')

    df1 = pd.DataFrame(df1['# gene-model: GENCODE v36'], index=df1['# gene-model: GENCODE v36'].index)
    df1 = df1.reset_index()

    df1.columns = df1.iloc[0]
    df1 = df1.drop(range(5))

    df1 = df1[df1['gene_name'].isin([
    'ALDOA',
    'ANGPTL4',
    'ANLN',
    'BNC1',
    'C20orf20', #not present
    'CA9',
    'CDKN3',
    'COL4A6',
    'DCBLD1',
    'ENO1',
    'FAM83B',
    'FOSL1',
    'GNAI1',
    'HIG2', #not present
    'KCTD11',
    'KRT17',
    'LDHA',
    'MPRS17', #not present
    'P4HA1',
    'PGAM1',
    'PGK1',
    'SDC1',
    'SLC16A1',
    'SLC2A1',
    'TPI1',
    'VEGFA',])]

    df1.index = df1['gene_name']
    df1.index.name = None

    df1 = df1.iloc[:, -6:].stack()
    df1.index = ['_'.join(map(str, idx)) for idx in df1.index]

    df = pd.concat([df, pd.DataFrame(df1).T])
df = pd.concat([pd.DataFrame(folders), df.reset_index(drop=True)], axis=1)
df = df.rename({0: 'file_id'}, axis='columns')

# %%
import json
import pandas as pd
from sklearn.model_selection import train_test_split

df = pd.read_csv('rnaseq.tsv', sep='\t')

meta = json.load(open('metadata.cart.2024-02-01.json'))
df2 = pd.DataFrame(columns=['file_id', 'case_id'])
for i in meta:
    df3 = pd.DataFrame([i['file_id'], i['associated_entities'][0]['case_id']]).T
    df3.columns = ['file_id', 'case_id']
    df2 = pd.concat([df2, df3])
df = pd.merge(df, df2, on='file_id', how='left')

df3 = pd.read_csv('output.csv')
df = pd.merge(df, df3, on='case_id', how='left')

X = df.drop(columns=['file_id', 'case_id', 'vital_status']).apply(pd.to_numeric)
y = df['vital_status'].map({'Alive': True, 'Dead': False})

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2)

# %%
import matplotlib.pyplot as plt
from sklearn.decomposition import PCA
from sklearn.preprocessing import StandardScaler

principal_components = PCA(n_components=2).fit_transform(StandardScaler().fit_transform(X))
principal_df = pd.DataFrame(data=principal_components, columns=['PC1', 'PC2'])

plt.figure(figsize=(8, 6))
plt.scatter(principal_df['PC1'], principal_df['PC2'], c=y, cmap='viridis')
plt.show()

# %%
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import accuracy_score

classifier = RandomForestClassifier()
classifier.fit(X_train, y_train)
y_pred = classifier.predict(X_test)
accuracy = accuracy_score(y_test, y_pred)
print("Accuracy:", accuracy)
# Out:
# Accuracy: 0.6283185840707964

# %%
from keras.layers import Input, Dense
from keras.models import Model
import matplotlib.pyplot as plt
from sklearn.decomposition import PCA
from sklearn.preprocessing import StandardScaler

encoding_dim = 10

input_img = Input(shape=(X.shape[1],))
encoded = Dense(encoding_dim, activation='relu')(input_img)
decoded = Dense(X.shape[1], activation='sigmoid')(encoded)
autoencoder = Model(input_img, decoded)
encoder = Model(input_img, encoded)
encoded_input = Input(shape=(encoding_dim,))
decoder_layer = autoencoder.layers[-1]
decoder = Model(encoded_input, decoder_layer(encoded_input))
autoencoder.compile(optimizer='adam', loss='binary_crossentropy')

autoencoder.fit(X, X, epochs=50)

encoded_imgs = encoder.predict(X)

principal_components = PCA(n_components=2).fit_transform(StandardScaler().fit_transform(encoded_imgs))
principal_df = pd.DataFrame(data=principal_components, columns=['PC1', 'PC2'])

plt.figure(figsize=(8, 6))
plt.scatter(principal_df['PC1'], principal_df['PC2'], c=y, cmap='viridis')
plt.show()
# Out:
# Epoch 1/50
# 18/18 [==============================] - 0s 663us/step - loss: -67796976.0000
# Epoch 2/50
# 18/18 [==============================] - 0s 561us/step - loss: -248317056.0000
# Epoch 3/50
# 18/18 [==============================] - 0s 438us/step - loss: -585925248.0000
# Epoch 4/50
# 18/18 [==============================] - 0s 525us/step - loss: -1205101824.0000
# Epoch 5/50
# 18/18 [==============================] - 0s 441us/step - loss: -2223510784.0000
# Epoch 6/50
# 18/18 [==============================] - 0s 519us/step - loss: -3651639808.0000
# Epoch 7/50
# 18/18 [==============================] - 0s 482us/step - loss: -5518295040.0000
# Epoch 8/50
# 18/18 [==============================] - 0s 486us/step - loss: -7782688768.0000
# Epoch 9/50
# 18/18 [==============================] - 0s 505us/step - loss: -10609848320.0000
# Epoch 10/50
# 18/18 [==============================] - 0s 485us/step - loss: -14125559808.0000
# Epoch 11/50
# ...

# %%
import numpy as np
from sklearn.model_selection import train_test_split
from keras.models import Sequential
from keras.layers import Dense

encoder = Sequential()
encoder.add(Dense(128, activation='relu', input_shape=(input_dim,)))
encoder.add(Dense(64, activation='relu'))
encoder.add(Dense(encoding_dim, activation='relu'))  # Encoding layer
encoder.add(Dense(64, activation='relu'))
encoder.add(Dense(128, activation='relu'))
encoder.add(Dense(input_dim, activation='relu'))

# Compile the encoder model
encoder.compile(optimizer='adam', loss='mse')

# Train the encoder model
history = encoder.fit(X_train, X_train,
                      epochs=100,
                      batch_size=256,
                      shuffle=True,
                      validation_data=(X_test, X_test))

# Evaluate the model
score = encoder.evaluate(X_test, X_test)
print("Test loss:", score)

# Get the encoded representation of the data
encoded_data = encoder.predict(X_train)

# %%
from keras.layers import Input, Dense
from keras.models import Model
import matplotlib.pyplot as plt
from sklearn.decomposition import PCA
from sklearn.preprocessing import StandardScaler

encoding_dim = 10

input_img = Input(shape=(X.shape[1],))
encoded = Dense(encoding_dim, activation='relu')(input_img)
decoded = Dense(X.shape[1], activation='sigmoid')(encoded)
autoencoder = Model(input_img, decoded)
encoder = Model(input_img, encoded)
encoded_input = Input(shape=(encoding_dim,))
decoder_layer = autoencoder.layers[-1]
decoder = Model(encoded_input, decoder_layer(encoded_input))
autoencoder.compile(optimizer='adam', loss='binary_crossentropy')

autoencoder.fit(X_train, X_train, epochs=50, validation_data=(X_test, X_test))

encoded_imgs = encoder.predict(X_train)

principal_components = PCA(n_components=2).fit_transform(StandardScaler().fit_transform(encoded_imgs))
principal_df = pd.DataFrame(data=principal_components, columns=['PC1', 'PC2'])

plt.figure(figsize=(8, 6))
plt.scatter(principal_df['PC1'], principal_df['PC2'], c=y, cmap='viridis')
plt.show()
# Out:
# Epoch 1/50
# 15/15 [==============================] - 0s 6ms/step - loss: -81417088.0000 - val_loss: -136916896.0000
# Epoch 2/50
# 15/15 [==============================] - 0s 1ms/step - loss: -228086960.0000 - val_loss: -318800608.0000
# Epoch 3/50
# 15/15 [==============================] - 0s 1ms/step - loss: -477264928.0000 - val_loss: -615307008.0000
# Epoch 4/50
# 15/15 [==============================] - 0s 1ms/step - loss: -878605696.0000 - val_loss: -1104586112.0000
# Epoch 5/50
# 15/15 [==============================] - 0s 1ms/step - loss: -1500448768.0000 - val_loss: -1830852224.0000
# Epoch 6/50
# 15/15 [==============================] - 0s 1ms/step - loss: -2405008128.0000 - val_loss: -2846299136.0000
# Epoch 7/50
# 15/15 [==============================] - 0s 1ms/step - loss: -3621338880.0000 - val_loss: -4148014080.0000
# Epoch 8/50
# 15/15 [==============================] - 0s 1ms/step - loss: -5102197248.0000 - val_loss: -5685278208.0000
# Epoch 9/50
# ...
